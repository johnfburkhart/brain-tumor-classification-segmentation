# %%
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, random_split
import torchvision.transforms as transforms
from PIL import Image

processed_dir = "./processed_data/"

# %%
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, random_split
import torchvision.transforms as transforms
from PIL import Image

processed_dir = "./processed_data/"
img_size = (224,224)


train_transform = transforms.Compose([
    transforms.Resize(img_size),
    transforms.RandomHorizontalFlip(p = 0.5),
    transforms.GaussianBlur(3),
    transforms.ToTensor(),
    transforms.Normalize(
    mean=[0.5, 0.5, 0.5],
    std=[0.5, 0.5, 0.5]), 
])

test_transform = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize(
    mean=[0.5, 0.5, 0.5],
    std=[0.5, 0.5, 0.5]), 
])

train_dataset = ImageFolder(root = "./processed_data/train/", transform = train_transform)
test_dataset = ImageFolder(root = "./processed_data/test/", transform = test_transform)
train_dataset.samples
# Out:
# [('./processed_data/train/no/1 no.jpeg', 0),
#  ('./processed_data/train/no/10 no.jpg', 0),
#  ('./processed_data/train/no/11 no.jpg', 0),
#  ('./processed_data/train/no/13 no.jpg', 0),
#  ('./processed_data/train/no/14 no.jpg', 0),
#  ('./processed_data/train/no/15 no.jpg', 0),
#  ('./processed_data/train/no/17 no.jpg', 0),
#  ('./processed_data/train/no/18 no.jpg', 0),
#  ('./processed_data/train/no/21 no.jpg', 0),
#  ('./processed_data/train/no/22 no.jpg', 0),
#  ('./processed_data/train/no/23 no.jpg', 0),
#  ('./processed_data/train/no/24 no.jpg', 0),
#  ('./processed_data/train/no/25 no.jpg', 0),
#  ('./processed_data/train/no/26 no.jpg', 0),
#  ('./processed_data/train/no/28 no.jpg', 0),
#  ('./processed_data/train/no/29 no.jpg', 0),
#  ('./processed_data/train/no/3 no.jpg', 0),
#  ('./processed_data/train/no/31 no.jpg', 0),
#  ('./processed_data/train/no/32 no.jpg', 0),
#  ('./processed_data/train/no/33 no.jpg', 0),
#  ('./processed_data/train/no/34 no.jpg', 0),
#  ('./processed_data/train/no/35 no.jpg', 0),
#  ('./processed_data/train/no/37 no.jpg', 0),
#  ('./processed_data/train/no/38 no.jpg', 0),
#  ('./processed_data/train/no/4 no.jpg', 0),
#  ('./processed_data/train/no/40 no.jpg', 0),
#  ('./processed_data/train/no/42 no.jpg', 0),
#  ('./processed_data/train/no/43 no.jpg', 0),
#  ('./processed_data/train/no/46 no.jpg', 0),
#  ('./processed_data/train/no/47 no.jpg', 0),
#  ('./processed_data/train/no/48 no.jpeg', 0),
#  ('./processed_data/train/no/49 no.jpg', 0),
#  ('./processed_data/train/no/50 no.jpg', 0),
#  ('./processed_data/train/no/6 no.jpg', 0),
#  ('./processed_data/train/no/7 no.jpg', 0),
#  ('./processed_data/train/no/8 no.jpg', 0),
#  ('./processed_data/train/no/9 no.jpg', 0),
#  ('./processed_data/train/no/N1.JPG', 0),
#  ('./processed_data/train/no/N11.jpg', 0),
#  ('./processed_data/train/no/N15.jpg', 0),
#  ('./processed_data/train/no/N16.jpg', 0),
#  ('./processed_data/train/no/N17.jpg', 0),
#  ('./processed_data/train/no/N19.JPG', 0),
#  ('./processed_data/train/no/N2.JPG', 0),
#  ('./processed_data/train/no/N20.JPG', 0),
#  ('./processed_data/train/no/N26.JPG', 0),
#  ('./processed_data/train/no/N3.jpg', 0),
#  ('./processed_data/train/no/N5.jpg', 0),
#  ('./processed_data/train/no/N6.jpg', 0),
#  ('./processed_data/train/no/No11.jpg', 0),
#  ('./processed_data/train/no/No12.jpg', 0),
#  ('./processed_data/train/no/No13.jpg', 0),
#  ('./processed_data/train/no/No14.jpg', 0),
#  ('./processed_data/train/no/No15.jpg', 0),
#  ('./processed_data/train/no/No16.jpg', 0),
#  ('./processed_data/train/no/No17.jpg', 0),
#  ('./processed_data/train/no/No20.jpg', 0),
#  ('./processed_data/train/no/No21.jpg', 0),
#  ('./processed_data/train/no/No22.jpg', 0),
#  ('./processed_data/train/no/no 1.jpg', 0),
#  ('./processed_data/train/no/no 10.jpg', 0),
#  ('./processed_data/train/no/no 100.jpg', 0),
#  ('./processed_data/train/no/no 3.jpg', 0),
#  ('./processed_data/train/no/no 4.jpg', 0),
#  ('./processed_data/train/no/no 5.jpeg', 0),
#  ('./processed_data/train/no/no 6.jpg', 0),
#  ('./processed_data/train/no/no 7.jpeg', 0),
#  ('./processed_data/train/no/no 8.jpg', 0),
#  ('./processed_data/train/no/no 89.jpg', 0),
#  ('./processed_data/train/no/no 91.jpeg', 0),
#  ('./processed_data/train/no/no 92.jpg', 0),
#  ('./processed_data/train/no/no 94.jpg', 0),
#  ('./processed_data/train/no/no 95.jpg', 0),
#  ('./processed_data/train/no/no 97.jpg', 0),
#  ('./processed_data/train/no/no 98.jpg', 0),
#  ('./processed_data/train/no/no 99.jpg', 0),
#  ('./processed_data/train/no/no.jpg', 0),
#  ('./processed_data/train/yes/Y1.jpg', 1),
#  ('./processed_data/train/yes/Y10.jpg', 1),
#  ('./processed_data/train/yes/Y100.JPG', 1),
#  ('./processed_data/train/yes/Y101.jpg', 1),
#  ('./processed_data/train/yes/Y102.jpg', 1),
#  ('./processed_data/train/yes/Y104.jpg', 1),
#  ('./processed_data/train/yes/Y107.jpg', 1),
#  ('./processed_data/train/yes/Y108.jpg', 1),
#  ('./processed_data/train/yes/Y109.JPG', 1),
#  ('./processed_data/train/yes/Y11.jpg', 1),
#  ('./processed_data/train/yes/Y112.JPG', 1),
#  ('./processed_data/train/yes/Y113.JPG', 1),
#  ('./processed_data/train/yes/Y115.JPG', 1),
#  ('./processed_data/train/yes/Y116.JPG', 1),
#  ('./processed_data/train/yes/Y12.jpg', 1),
#  ('./processed_data/train/yes/Y120.JPG', 1),
#  ('./processed_data/train/yes/Y13.jpg', 1),
#  ('./processed_data/train/yes/Y14.jpg', 1),
#  ('./processed_data/train/yes/Y146.JPG', 1),
#  ('./processed_data/train/yes/Y147.JPG', 1),
#  ('./processed_data/train/yes/Y148.JPG', 1),
#  ('./processed_data/train/yes/Y15.jpg', 1),
#  ('./processed_data/train/yes/Y156.JPG', 1),
#  ('./processed_data/train/yes/Y157.JPG', 1),
#  ('./processed_data/train/yes/Y158.JPG', 1),
#  ('./processed_data/train/yes/Y159.JPG', 1),
#  ('./processed_data/train/yes/Y16.JPG', 1),
#  ('./processed_data/train/yes/Y160.JPG', 1),
#  ('./processed_data/train/yes/Y161.JPG', 1),
#  ('./processed_data/train/yes/Y162.jpg', 1),
#  ('./processed_data/train/yes/Y163.JPG', 1),
#  ('./processed_data/train/yes/Y164.JPG', 1),
#  ('./processed_data/train/yes/Y165.JPG', 1),
#  ('./processed_data/train/yes/Y166.JPG', 1),
#  ('./processed_data/train/yes/Y167.JPG', 1),
#  ('./processed_data/train/yes/Y168.jpg', 1),
#  ('./processed_data/train/yes/Y169.jpg', 1),
#  ('./processed_data/train/yes/Y17.jpg', 1),
#  ('./processed_data/train/yes/Y170.JPG', 1),
#  ('./processed_data/train/yes/Y18.JPG', 1),
#  ('./processed_data/train/yes/Y182.JPG', 1),
#  ('./processed_data/train/yes/Y183.jpg', 1),
#  ('./processed_data/train/yes/Y185.jpg', 1),
#  ('./processed_data/train/yes/Y187.jpg', 1),
#  ('./processed_data/train/yes/Y188.jpg', 1),
#  ('./processed_data/train/yes/Y19.JPG', 1),
#  ('./processed_data/train/yes/Y192.JPG', 1),
#  ('./processed_data/train/yes/Y193.JPG', 1),
#  ('./processed_data/train/yes/Y194.jpg', 1),
#  ('./processed_data/train/yes/Y2.jpg', 1),
#  ('./processed_data/train/yes/Y21.jpg', 1),
#  ('./processed_data/train/yes/Y22.jpg', 1),
#  ('./processed_data/train/yes/Y23.JPG', 1),
#  ('./processed_data/train/yes/Y24.jpg', 1),
#  ('./processed_data/train/yes/Y242.JPG', 1),
#  ('./processed_data/train/yes/Y244.JPG', 1),
#  ('./processed_data/train/yes/Y246.JPG', 1),
#  ('./processed_data/train/yes/Y247.JPG', 1),
#  ('./processed_data/train/yes/Y248.JPG', 1),
#  ('./processed_data/train/yes/Y249.JPG', 1),
#  ('./processed_data/train/yes/Y25.jpg', 1),
#  ('./processed_data/train/yes/Y250.jpg', 1),
#  ('./processed_data/train/yes/Y251.JPG', 1),
#  ('./processed_data/train/yes/Y252.jpg', 1),
#  ('./processed_data/train/yes/Y253.JPG', 1),
#  ('./processed_data/train/yes/Y254.jpg', 1),
#  ('./processed_data/train/yes/Y257.jpg', 1),
#  ('./processed_data/train/yes/Y258.JPG', 1),
#  ('./processed_data/train/yes/Y259.JPG', 1),
#  ('./processed_data/train/yes/Y26.jpg', 1),
#  ('./processed_data/train/yes/Y27.jpg', 1),
#  ('./processed_data/train/yes/Y28.jpg', 1),
#  ('./processed_data/train/yes/Y29.jpg', 1),
#  ('./processed_data/train/yes/Y3.jpg', 1),
#  ('./processed_data/train/yes/Y30.jpg', 1),
#  ('./processed_data/train/yes/Y31.jpg', 1),
#  ('./processed_data/train/yes/Y32.jpg', 1),
#  ('./processed_data/train/yes/Y33.jpg', 1),
#  ('./processed_data/train/yes/Y34.jpg', 1),
#  ('./processed_data/train/yes/Y37.jpg', 1),
#  ('./processed_data/train/yes/Y39.jpg', 1),
#  ('./processed_data/train/yes/Y4.jpg', 1),
#  ('./processed_data/train/yes/Y40.JPG', 1),
#  ('./processed_data/train/yes/Y42.jpg', 1),
#  ('./processed_data/train/yes/Y45.JPG', 1),
#  ('./processed_data/train/yes/Y49.JPG', 1),
#  ('./processed_data/train/yes/Y50.JPG', 1),
#  ('./processed_data/train/yes/Y51.jpg', 1),
#  ('./processed_data/train/yes/Y53.jpg', 1),
#  ('./processed_data/train/yes/Y54.jpg', 1),
#  ('./processed_data/train/yes/Y55.jpg', 1),
#  ('./processed_data/train/yes/Y56.jpg', 1),
#  ('./processed_data/train/yes/Y58.JPG', 1),
#  ('./processed_data/train/yes/Y6.jpg', 1),
#  ('./processed_data/train/yes/Y60.jpg', 1),
#  ('./processed_data/train/yes/Y61.jpg', 1),
#  ('./processed_data/train/yes/Y62.jpg', 1),
#  ('./processed_data/train/yes/Y65.JPG', 1),
#  ('./processed_data/train/yes/Y66.JPG', 1),
#  ('./processed_data/train/yes/Y67.JPG', 1),
#  ('./processed_data/train/yes/Y69.jpg', 1),
#  ('./processed_data/train/yes/Y7.jpg', 1),
#  ('./processed_data/train/yes/Y70.jpg', 1),
#  ('./processed_data/train/yes/Y71.JPG', 1),
#  ('./processed_data/train/yes/Y73.jpg', 1),
#  ('./processed_data/train/yes/Y74.jpg', 1),
#  ('./processed_data/train/yes/Y75.JPG', 1),
#  ('./processed_data/train/yes/Y77.jpg', 1),
#  ('./processed_data/train/yes/Y78.jpg', 1),
#  ('./processed_data/train/yes/Y79.jpg', 1),
#  ('./processed_data/train/yes/Y8.jpg', 1),
#  ('./processed_data/train/yes/Y82.jpg', 1),
#  ('./processed_data/train/yes/Y85.JPG', 1),
#  ('./processed_data/train/yes/Y86.JPG', 1),
#  ('./processed_data/train/yes/Y89.JPG', 1),
#  ('./processed_data/train/yes/Y9.jpg', 1),
#  ('./processed_data/train/yes/Y90.jpg', 1),
#  ('./processed_data/train/yes/Y91.jpg', 1),
#  ('./processed_data/train/yes/Y92.jpg', 1),
#  ('./processed_data/train/yes/Y92.png', 1),
#  ('./processed_data/train/yes/Y95.jpg', 1),
#  ('./processed_data/train/yes/Y96.jpg', 1),
#  ('./processed_data/train/yes/Y97.JPG', 1),
#  ('./processed_data/train/yes/Y98.JPG', 1)]

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size = 32, shuffle = False)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models


class SimpleCNN(nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(32 * 56 * 56, 128)
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 32 * 56 * 56)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return x


model = SimpleCNN(num_classes=2)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=1e-4)

# %%
num_epochs = 50
train_accuracy = []
test_accuracy = []

for epoch in range(num_epochs):
    # Training phase
    model.train()  # Set model to training mode
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    for images, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # Calculate training accuracy
        _, predicted_train = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted_train == labels).sum().item()
        
        running_loss += loss.item()
    
    train_accuracy.append(100 * correct_train / total_train)
    
    # Testing phase
    model.eval()  # Set model to evaluation mode
    correct_test = 0
    total_test = 0
    with torch.no_grad():
        for images, labels in test_loader:
            outputs = model(images)
            _, predicted_test = torch.max(outputs.data, 1)
            total_test += labels.size(0)
            correct_test += (predicted_test == labels).sum().item()
    
    test_accuracy.append(100 * correct_test / total_test)
    
    # Print training and testing accuracy
    print(f'Epoch [{epoch + 1}/{num_epochs}], Train Accuracy: {train_accuracy[-1]:.2f}%, Test Accuracy: {test_accuracy[-1]:.2f}%')
# Out:
# Epoch [1/50], Train Accuracy: 61.69%, Test Accuracy: 43.06%
# Epoch [2/50], Train Accuracy: 61.69%, Test Accuracy: 43.06%
# Epoch [3/50], Train Accuracy: 61.69%, Test Accuracy: 43.06%
# Epoch [4/50], Train Accuracy: 61.69%, Test Accuracy: 43.06%
# Epoch [5/50], Train Accuracy: 61.69%, Test Accuracy: 43.06%
# Epoch [6/50], Train Accuracy: 61.69%, Test Accuracy: 43.06%
# Epoch [7/50], Train Accuracy: 61.69%, Test Accuracy: 43.06%
# Epoch [8/50], Train Accuracy: 61.69%, Test Accuracy: 43.06%
# Epoch [9/50], Train Accuracy: 62.69%, Test Accuracy: 45.83%
# Epoch [10/50], Train Accuracy: 69.65%, Test Accuracy: 52.78%
# Epoch [11/50], Train Accuracy: 69.15%, Test Accuracy: 51.39%
# Epoch [12/50], Train Accuracy: 70.65%, Test Accuracy: 47.22%
# Epoch [13/50], Train Accuracy: 72.14%, Test Accuracy: 56.94%
# Epoch [14/50], Train Accuracy: 75.12%, Test Accuracy: 58.33%
# Epoch [15/50], Train Accuracy: 72.14%, Test Accuracy: 58.33%
# Epoch [16/50], Train Accuracy: 74.63%, Test Accuracy: 58.33%
# Epoch [17/50], Train Accuracy: 69.15%, Test Accuracy: 58.33%
# Epoch [18/50], Train Accuracy: 79.10%, Test Accuracy: 68.06%
# Epoch [19/50], Train Accuracy: 75.62%, Test Accuracy: 55.56%
# Epoch [20/50], Train Accuracy: 66.67%, Test Accuracy: 62.50%
# Epoch [21/50], Train Accuracy: 78.61%, Test Accuracy: 62.50%
# Epoch [22/50], Train Accuracy: 75.12%, Test Accuracy: 65.28%
# Epoch [23/50], Train Accuracy: 81.09%, Test Accuracy: 68.06%
# Epoch [24/50], Train Accuracy: 82.09%, Test Accuracy: 58.33%
# Epoch [25/50], Train Accuracy: 78.11%, Test Accuracy: 80.56%
# Epoch [26/50], Train Accuracy: 83.58%, Test Accuracy: 70.83%
# Epoch [27/50], Train Accuracy: 85.07%, Test Accuracy: 84.72%
# Epoch [28/50], Train Accuracy: 84.58%, Test Accuracy: 76.39%
# Epoch [29/50], Train Accuracy: 88.06%, Test Accuracy: 77.78%
# Epoch [30/50], Train Accuracy: 84.58%, Test Accuracy: 84.72%
# Epoch [31/50], Train Accuracy: 85.07%, Test Accuracy: 84.72%
# Epoch [32/50], Train Accuracy: 81.09%, Test Accuracy: 79.17%
# Epoch [33/50], Train Accuracy: 81.09%, Test Accuracy: 56.94%
# Epoch [34/50], Train Accuracy: 81.59%, Test Accuracy: 77.78%
# Epoch [35/50], Train Accuracy: 84.58%, Test Accuracy: 86.11%
# Epoch [36/50], Train Accuracy: 90.05%, Test Accuracy: 63.89%
# Epoch [37/50], Train Accuracy: 88.06%, Test Accuracy: 83.33%
# Epoch [38/50], Train Accuracy: 92.04%, Test Accuracy: 73.61%
# Epoch [39/50], Train Accuracy: 92.54%, Test Accuracy: 80.56%
# Epoch [40/50], Train Accuracy: 95.02%, Test Accuracy: 77.78%
# Epoch [41/50], Train Accuracy: 93.53%, Test Accuracy: 76.39%
# Epoch [42/50], Train Accuracy: 93.53%, Test Accuracy: 84.72%
# Epoch [43/50], Train Accuracy: 93.53%, Test Accuracy: 81.94%
# Epoch [44/50], Train Accuracy: 96.52%, Test Accuracy: 81.94%
# Epoch [45/50], Train Accuracy: 94.03%, Test Accuracy: 80.56%
# Epoch [46/50], Train Accuracy: 95.02%, Test Accuracy: 79.17%
# Epoch [47/50], Train Accuracy: 96.02%, Test Accuracy: 83.33%
# Epoch [48/50], Train Accuracy: 94.53%, Test Accuracy: 84.72%
# Epoch [49/50], Train Accuracy: 93.53%, Test Accuracy: 75.00%
# Epoch [50/50], Train Accuracy: 91.04%, Test Accuracy: 72.22%

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plot training and testing accuracy
plt.plot(train_accuracy, label='Train Accuracy', marker = 'o')
plt.plot(test_accuracy, label='Test Accuracy', marker = 'o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training and Testing Accuracy')
plt.legend()
plt.show()

# Report final accuracy on test set
print(f'Final Accuracy on Test Set: {test_accuracy[-1]:.2f}%')
np.mean(test_accuracy)
# Out:
# Final Accuracy on Test Set: 72.22%
# 66.22222222222221

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

model.eval()

# Initialize lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Make predictions on the dataset
with torch.no_grad():
    for images, labels in test_loader:
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        true_labels.extend(labels.numpy())
        predicted_labels.extend(predicted.numpy())
        
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
ConfusionMatrixDisplay(conf_matrix, display_labels=['Yes', 'No']).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Load pre-trained VGG model
vgg_model = models.vgg19(pretrained=True)

# Freeze parameters of pre-trained layers
for param in vgg_model.parameters():
    param.requires_grad = False

# Modify classifier for binary classification
num_features = vgg_model.classifier[6].in_features
vgg_model.classifier[6] = nn.Linear(num_features, 2)  # Output layer for binary classification

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(vgg_model.parameters(), lr=0.001, weight_decay=1e-4)
# Out:
# /home/frankburkhart/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/frankburkhart/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
num_epochs = 50
train_accuracy = []
test_accuracy = []

model = vgg_model

for epoch in range(num_epochs):
    # Training phase
    model.train()  # Set model to training mode
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    for images, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # Calculate training accuracy
        _, predicted_train = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted_train == labels).sum().item()
        
        running_loss += loss.item()
    
    train_accuracy.append(100 * correct_train / total_train)
    
    # Testing phase
    model.eval()  # Set model to evaluation mode
    correct_test = 0
    total_test = 0
    with torch.no_grad():
        for images, labels in test_loader:
            outputs = model(images)
            _, predicted_test = torch.max(outputs.data, 1)
            total_test += labels.size(0)
            correct_test += (predicted_test == labels).sum().item()
    
    test_accuracy.append(100 * correct_test / total_test)
    
    # Print training and testing accuracy
    print(f'Epoch [{epoch + 1}/{num_epochs}], Train Accuracy: {train_accuracy[-1]:.2f}%, Test Accuracy: {test_accuracy[-1]:.2f}%')
# Out:
# Epoch [1/50], Train Accuracy: 60.70%, Test Accuracy: 73.61%
# Epoch [2/50], Train Accuracy: 73.13%, Test Accuracy: 58.33%
# Epoch [3/50], Train Accuracy: 76.12%, Test Accuracy: 76.39%
# Epoch [4/50], Train Accuracy: 80.60%, Test Accuracy: 66.67%
# Epoch [5/50], Train Accuracy: 82.09%, Test Accuracy: 72.22%
# Epoch [6/50], Train Accuracy: 82.59%, Test Accuracy: 69.44%
# Epoch [7/50], Train Accuracy: 82.09%, Test Accuracy: 70.83%
# Epoch [8/50], Train Accuracy: 81.59%, Test Accuracy: 75.00%
# Epoch [9/50], Train Accuracy: 81.09%, Test Accuracy: 75.00%
# Epoch [10/50], Train Accuracy: 83.08%, Test Accuracy: 75.00%
# Epoch [11/50], Train Accuracy: 85.57%, Test Accuracy: 72.22%
# Epoch [12/50], Train Accuracy: 87.56%, Test Accuracy: 79.17%
# Epoch [13/50], Train Accuracy: 86.57%, Test Accuracy: 77.78%
# Epoch [14/50], Train Accuracy: 85.57%, Test Accuracy: 73.61%
# Epoch [15/50], Train Accuracy: 85.57%, Test Accuracy: 73.61%
# Epoch [16/50], Train Accuracy: 83.08%, Test Accuracy: 77.78%
# Epoch [17/50], Train Accuracy: 90.05%, Test Accuracy: 73.61%
# Epoch [18/50], Train Accuracy: 83.08%, Test Accuracy: 80.56%
# Epoch [19/50], Train Accuracy: 88.06%, Test Accuracy: 75.00%
# Epoch [20/50], Train Accuracy: 87.56%, Test Accuracy: 75.00%
# Epoch [21/50], Train Accuracy: 91.04%, Test Accuracy: 80.56%
# Epoch [22/50], Train Accuracy: 86.07%, Test Accuracy: 79.17%
# Epoch [23/50], Train Accuracy: 84.08%, Test Accuracy: 76.39%
# Epoch [24/50], Train Accuracy: 89.05%, Test Accuracy: 75.00%
# Epoch [25/50], Train Accuracy: 89.05%, Test Accuracy: 75.00%
# Epoch [26/50], Train Accuracy: 88.56%, Test Accuracy: 75.00%
# Epoch [27/50], Train Accuracy: 91.54%, Test Accuracy: 77.78%
# Epoch [28/50], Train Accuracy: 91.04%, Test Accuracy: 76.39%
# Epoch [29/50], Train Accuracy: 89.05%, Test Accuracy: 79.17%
# Epoch [30/50], Train Accuracy: 86.57%, Test Accuracy: 79.17%
# Epoch [31/50], Train Accuracy: 88.06%, Test Accuracy: 79.17%
# Epoch [32/50], Train Accuracy: 87.56%, Test Accuracy: 79.17%
# Epoch [33/50], Train Accuracy: 89.05%, Test Accuracy: 79.17%
# Epoch [34/50], Train Accuracy: 90.05%, Test Accuracy: 79.17%
# Epoch [35/50], Train Accuracy: 90.05%, Test Accuracy: 80.56%
# Epoch [36/50], Train Accuracy: 87.06%, Test Accuracy: 83.33%
# Epoch [37/50], Train Accuracy: 88.06%, Test Accuracy: 80.56%
# Epoch [38/50], Train Accuracy: 90.05%, Test Accuracy: 81.94%
# Epoch [39/50], Train Accuracy: 84.08%, Test Accuracy: 80.56%
# Epoch [40/50], Train Accuracy: 86.57%, Test Accuracy: 81.94%
# Epoch [41/50], Train Accuracy: 90.05%, Test Accuracy: 77.78%
# Epoch [42/50], Train Accuracy: 88.56%, Test Accuracy: 79.17%
# Epoch [43/50], Train Accuracy: 90.05%, Test Accuracy: 81.94%
# Epoch [44/50], Train Accuracy: 87.56%, Test Accuracy: 81.94%
# Epoch [45/50], Train Accuracy: 90.05%, Test Accuracy: 83.33%
# Epoch [46/50], Train Accuracy: 89.55%, Test Accuracy: 81.94%
# Epoch [47/50], Train Accuracy: 88.06%, Test Accuracy: 75.00%
# Epoch [48/50], Train Accuracy: 90.05%, Test Accuracy: 83.33%
# Epoch [49/50], Train Accuracy: 90.55%, Test Accuracy: 86.11%
# Epoch [50/50], Train Accuracy: 89.05%, Test Accuracy: 79.17%

# %%
# Plot training and testing accuracy
plt.plot(train_accuracy, label='Train Accuracy', marker = "o")
plt.plot(test_accuracy, label='Test Accuracy', marker = "o")
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training and Testing Accuracy')
plt.legend()
plt.show()

# Report final accuracy on test set
print(f'Final Accuracy on Test Set: {test_accuracy[-1]:.2f}%')
# Out:
# Final Accuracy on Test Set: 79.17%

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

model.eval()

# Initialize lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Make predictions on the dataset
with torch.no_grad():
    for images, labels in test_loader:
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        true_labels.extend(labels.numpy())
        predicted_labels.extend(predicted.numpy())
        
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
ConfusionMatrixDisplay(conf_matrix, display_labels=['Yes', 'No']).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
np.mean(test_accuracy)
# Out:
# 77.19444444444444

# %%
def evaluate_model(model, test_loader):
    model.eval()  # Set model to evaluation mode
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = 100 * correct / total
    return accuracy
evaluate_model(model, test_loader)
# Out:
# 75.0
